# %% [markdown]
# # Stage 11 — Data Augmentation
#
# **Not yet implemented.** Placeholder notebook reserving the slot in the pipeline
# numbering (`10`=labels, `11`=augmentation, `12x`=extraction per pipeline).
#
# **Planned scope (per the repo-restructure plan, option A):** augmentation writes
# new **dataset variants to disk** (not in-memory transforms at extraction time),
# so `12x_extract_*` notebooks can point at either the raw or an augmented figure
# set via config — no special-casing in the embedding format. This lets the same
# augmentation set be reused identically across every model pipeline being
# benchmarked in repo 3.
#
# **TODO:**
# - `src/augmentation.py` — augmentation transforms + dataset-variant writer (does not exist yet)
# - decide which augmentations are relevant for patent line-art figures (rotation,
#   perspective jitter, contrast/style perturbation for confound-robustness testing?)
# - config keys under `augmentation:` in `config.yaml` (output dir, transform list, variant name)

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
while not (ROOT / 'config.yaml').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

import pandas as pd
from src.config_loader import load_config
# from src import augmentation as aug  # not yet implemented
cfg = load_config()
raise NotImplementedError('11_augmentation: src/augmentation.py not yet written')
